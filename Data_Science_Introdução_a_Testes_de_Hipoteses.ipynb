# %% [markdown]
# <a href="https://colab.research.google.com/github/renanas/DataScience_Study/blob/main/Data_Science_Introdu%C3%A7%C3%A3o_a_Testes_de_Hipoteses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

tmdb = pd.read_csv('tmdb_5000_movies.csv')
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
import seaborn as sns

ax = sns.distplot(tmdb['vote_average'])
ax.set(xlabel = "Nota Media", ylabel= "Densidade")
ax.set_title("Media de votos em filmes no TMDB 5000")
# Out:
# <ipython-input-3-ea381f1fe60e>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb['vote_average'])
# Text(0.5, 1.0, 'Media de votos em filmes no TMDB 5000')

# %%
ax = sns.distplot(tmdb['vote_average'], norm_hist= False, kde= False)
ax.set(xlabel = "Nota Media", ylabel= "Frequencia")
ax.set_title("Media de votos em filmes no TMDB 5000")
# Out:
# <ipython-input-4-0586f83e5258>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb['vote_average'], norm_hist= False, kde= False)
# Text(0.5, 1.0, 'Media de votos em filmes no TMDB 5000')

# %%
ax = sns.boxplot(x=tmdb['vote_average'])
ax.set(xlabel = "Nota media do filme")
ax.set_title("Distribuição de nota media dos filmes do TMDB 5000")
# Out:
# Text(0.5, 1.0, 'Distribuição de nota media dos filmes do TMDB 5000')

# %%
tmdb.query("vote_average == 0")
# Out:
#        budget                                             genres  \
# 1464        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669        0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3670        0                  [{"id": 10751, "name": "Family"}]
# 3852        0                      [{"id": 18, "name": "Drama"}]
# 3855  3500000                [{"id": 99, "name": "Documentary"}]
# ...       ...                                                ...
# 4769        0  [{"id": 28, "name": "Action"}, {"id": 37, "nam...
# 4771        0                     [{"id": 27, "name": "Horror"}]
# 4780        0  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 4785        0                      [{"id": 18, "name": "Drama"}]
# 4794        0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
#
#                            homepage      id  \
# 1464                            NaN  310706
# 3669  http://www.romeothemovie.com/  113406
# 3670                            NaN  447027
# ...

# %%
tmdb.query("vote_average == 0 and vote_count != 0")
# Out:
#       budget genres homepage      id keywords original_language  \
# 4400       0     []      NaN  219716       []                en
#
#      original_title                                           overview  \
# 4400       Sparkler  Melba is a Californian trailer-park girl who i...
#
#       popularity production_companies production_countries release_date  \
# 4400    0.547654                   []                   []   1999-03-19
#
#       revenue  runtime spoken_languages    status tagline     title  \
# 4400        0     96.0               []  Released     NaN  Sparkler
#
#       vote_average  vote_count
# 4400           0.0           1

# %%
tmdb_10_votos_mais = tmdb.query("vote_count >= 10")
tmdb_10_votos_mais.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.392000e+03    4392.000000  4392.000000  4.392000e+03  4391.000000
# mean   3.164545e+07   49204.119991    23.448815  8.990969e+07   108.430881
# std    4.162736e+07   80136.249777    32.592158  1.682870e+08    21.014719
# min    0.000000e+00       5.000000     0.011697  0.000000e+00     0.000000
# 25%    2.895962e+06    8403.500000     6.512166  1.365700e+04    95.000000
# 50%    1.700000e+07   13084.500000    14.827784  2.685837e+07   105.000000
# 75%    4.200000e+07   46831.250000    30.258282  1.022818e+08   118.500000
# max    3.800000e+08  417859.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4392.000000   4392.000000
# mean       6.226935    754.441712
# std        0.893215   1272.263761
# min        1.900000     10.000000
# 25%        5.700000     83.750000
# 50%        6.300000    288.500000
# 75%        6.800000    831.000000
# ...

# %%
tmdb.query("vote_average == 10")
# Out:
#       budget                                             genres homepage  \
# 3519       0                     [{"id": 35, "name": "Comedy"}]      NaN
# 4045       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...      NaN
# 4247       1  [{"id": 10749, "name": "Romance"}, {"id": 35, ...      NaN
# 4662       0                     [{"id": 35, "name": "Comedy"}]      NaN
#
#           id                                           keywords  \
# 3519   89861  [{"id": 131, "name": "italy"}, {"id": 8250, "n...
# 4045   78373  [{"id": 1415, "name": "small town"}, {"id": 15...
# 4247  361505                                                 []
# 4662   40963        [{"id": 10183, "name": "independent film"}]
#
#      original_language         original_title  \
# 3519                en       Stiff Upper Lips
# 4045                en  Dancer, Texas Pop. 81
# 4247                en  Me You and Five Bucks
# 4662                en         Little Big Top
#
# ...

# %% [markdown]
# Há algo de estranho com os dados, não faz sentido filmes com notas 0 ou 10 pois tem poucos votos.
# Vou manter eles fora das nossas analises.

# %%
ax = sns.distplot(tmdb_10_votos_mais['vote_average'], norm_hist= False, kde= False)
ax.set(xlabel = "Nota Media", ylabel= "Frequencia")
ax.set_title("Media de votos em filmes no TMDB 5000 dentre os filmes com 10 votos ou mais ")
# Out:
# <ipython-input-10-6f92f2c1acdc>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb_10_votos_mais['vote_average'], norm_hist= False, kde= False)
# Text(0.5, 1.0, 'Media de votos em filmes no TMDB 5000 dentre os filmes com 10 votos ou mais ')

# %%
ax = sns.distplot(tmdb_10_votos_mais['vote_average'])
ax.set(xlabel = "Nota Media", ylabel= "Densidade")
ax.set_title("Media de votos em filmes no TMDB 5000 dentre os filmes com 10 votos ou mais ")
# Out:
# <ipython-input-11-5a4b3baffdc0>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb_10_votos_mais['vote_average'])
# Text(0.5, 1.0, 'Media de votos em filmes no TMDB 5000 dentre os filmes com 10 votos ou mais ')

# %%
ax = sns.boxplot(x=tmdb_10_votos_mais['vote_average'])
ax.set(xlabel = "Nota media do filme")
ax.set_title("Distribuição de nota media dos filmes do TMDB 5000 dentre os filmes com 10 votos ou mais")
# Out:
# Text(0.5, 1.0, 'Distribuição de nota media dos filmes do TMDB 5000 dentre os filmes com 10 votos ou mais')

# %% [markdown]
# Analisaremos o movielens

# %%
notas = pd.read_csv('ratings.csv')
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.groupby('movieId').mean()["rating"]
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: rating, Length: 9724, dtype: float64

# %%
nota_media_por_filme = notas.groupby('movieId').mean()["rating"]
nota_media_por_filme.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: rating, dtype: float64

# %%
ax = sns.distplot(nota_media_por_filme.values)
ax.set(xlabel = "Nota Media", ylabel= "Densidade")
ax.set_title("Media de votos em filmes no MovieLens 100 mil")
# Out:
# <ipython-input-16-221439fb72d0>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_por_filme.values)
# Text(0.5, 1.0, 'Media de votos em filmes no MovieLens 100 mil')

# %%
quantidade_de_votos_por_filme = notas.groupby("movieId").count()
quantidade_de_votos_por_filme
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 2           110     110        110
# 3            52      52         52
# 4             7       7          7
# 5            49      49         49
# ...         ...     ...        ...
# 193581        1       1          1
# 193583        1       1          1
# 193585        1       1          1
# 193587        1       1          1
# 193609        1       1          1
#
# [9724 rows x 3 columns]

# %%
quantidade_de_votos_por_filme.query("rating >= 10")
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 2           110     110        110
# 3            52      52         52
# 5            49      49         49
# 6           102     102        102
# ...         ...     ...        ...
# 174055       13      13         13
# 176371       18      18         18
# 177765       13      13         13
# 179819       12      12         12
# 187593       12      12         12
#
# [2269 rows x 3 columns]

# %%
filmes_com_pelo_menos_10_votos = quantidade_de_votos_por_filme.query("rating >= 10").index
filmes_com_pelo_menos_10_votos.values
# Out:
# array([     1,      2,      3, ..., 177765, 179819, 187593])

# %%
nota_media_dos_filmes_com_pelo_menos_10_votos = nota_media_por_filme.loc[filmes_com_pelo_menos_10_votos.values]
nota_media_dos_filmes_com_pelo_menos_10_votos.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 5    3.071429
# 6    3.946078
# Name: rating, dtype: float64

# %%
ax = sns.distplot(nota_media_dos_filmes_com_pelo_menos_10_votos.values)
ax.set(xlabel = "Nota Media", ylabel= "Densidade")
ax.set_title("Media de votos em filmes no MovieLens 100 mil com pelo menos 10 votos")
# Out:
# <ipython-input-21-b6c038821aeb>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_dos_filmes_com_pelo_menos_10_votos.values)
# Text(0.5, 1.0, 'Media de votos em filmes no MovieLens 100 mil com pelo menos 10 votos')

# %%
ax = sns.boxplot(x=nota_media_dos_filmes_com_pelo_menos_10_votos.values)
ax.set(xlabel = "Nota media do filme")
ax.set_title("Distribuição de nota media dos filmes do MovieLens 100 mil dentre os filmes com 10 votos ou mais")
# Out:
# Text(0.5, 1.0, 'Distribuição de nota media dos filmes do MovieLens 100 mil dentre os filmes com 10 votos ou mais')

# %%
ax = sns.distplot(nota_media_dos_filmes_com_pelo_menos_10_votos.values,
                  hist_kws = {'cumulative': True},
                  kde_kws = {'cumulative': True})
ax.set(xlabel = "Nota Media", ylabel= "% Acumulada por filmes")
ax.set_title("Media de votos em filmes no MovieLens 100 mil com pelo menos 10 votos")
# Out:
# <ipython-input-23-53504b204b73>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_dos_filmes_com_pelo_menos_10_votos.values,
# Text(0.5, 1.0, 'Media de votos em filmes no MovieLens 100 mil com pelo menos 10 votos')

# %% [markdown]
# Uma maneira visual de enchergar os dados e entender qual a porcentagem dos filmes avaliados.
# Exemplo: Dependendo da nota do filmes vamos entender se ele está acima ou a baixo da porcentagem dos filmes, ou seja, se um filme recebe nota 3.5 ele está a cima de 55% dos filmes avaliados

# %%
ax = sns.distplot(tmdb_10_votos_mais['vote_average'],
                  hist_kws = {'cumulative': True},
                  kde_kws = {'cumulative': True})
ax.set(xlabel = "Nota Media", ylabel= "% Acumulada por filmes")
ax.set_title("Media de votos em filmes no TMDB 5000 com pelo menos 10 votos")
# Out:
# <ipython-input-24-645661fa1f17>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb_10_votos_mais['vote_average'],
# Text(0.5, 1.0, 'Media de votos em filmes no TMDB 5000 com pelo menos 10 votos')

# %% [markdown]
# Apenas tendo uma noção visual do outro database(TMDB 5000)

# %% [markdown]
# # Analisando a distribuição dos dados capturados de outros campos do TMDB

# %%
ax = sns.distplot(tmdb_10_votos_mais['vote_count'])
ax.set(xlabel = "Numero de votos", ylabel= "Densidade")
ax.set_title("Numero de votos em filmes no TMDB 5000 com pelo menos 10 votos")
# Out:
# <ipython-input-25-18c575851629>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb_10_votos_mais['vote_count'])
# Text(0.5, 1.0, 'Numero de votos em filmes no TMDB 5000 com pelo menos 10 votos')

# %%
ax = sns.distplot(tmdb.query('budget > 0').budget)
ax.set(xlabel = "Budget (gastos)", ylabel= "Densidade")
ax.set_title("Budget em filmes no TMDB 5000")
# Out:
# <ipython-input-26-fb429620093d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.query('budget > 0').budget)
# Text(0.5, 1.0, 'Budget em filmes no TMDB 5000')

# %%
ax = sns.distplot(tmdb['popularity'])
ax.set(xlabel = "Popularidade", ylabel= "Densidade")
ax.set_title("Popularidade em filmes no TMDB 5000")
# Out:
# <ipython-input-27-3c9cb2566489>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb['popularity'])
# Text(0.5, 1.0, 'Popularidade em filmes no TMDB 5000')

# %%
tmdb['runtime'].isnull().sum()
# Out:
# 2

# %%
tmdb.query('runtime == 0')
# Out:
#        budget                                             genres  \
# 1011        0                     [{"id": 27, "name": "Horror"}]
# 3112        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669        0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3809  4000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 3953        0  [{"id": 10752, "name": "War"}, {"id": 18, "nam...
# 3992        0                                                 []
# 4068        0                                                 []
# 4118        0                                                 []
# 4205        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 4210        0                 [{"id": 10749, "name": "Romance"}]
# 4241  1500000                     [{"id": 35, "name": "Comedy"}]
# 4313        0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 4318        0                     [{"id": 27, "name": "Horror"}]
# ...

# %%
ax = sns.distplot(tmdb.query('runtime > 0')['runtime'].dropna())
ax.set(xlabel = "Tempo de duracao minuto", ylabel= "Densidade")
ax.set_title("Tempo de duracao em filmes no TMDB 5000")
# Out:
# <ipython-input-30-096ebe896610>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.query('runtime > 0')['runtime'].dropna())
# Text(0.5, 1.0, 'Tempo de duracao em filmes no TMDB 5000')

# %%
ax = sns.distplot(tmdb.query('runtime > 0')['runtime'].dropna(),
                  hist_kws = {'cumulative': True},
                  kde_kws = {'cumulative': True})
ax.set(xlabel = "Tempo de duracao minuto", ylabel= "% dos filmes")
ax.set_title("Tempo de duracao em filmes no TMDB 5000")
# Out:
# <ipython-input-31-2f97c6ccfbe0>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.query('runtime > 0')['runtime'].dropna(),
# Text(0.5, 1.0, 'Tempo de duracao em filmes no TMDB 5000')

# %%
tmdb.query('runtime > 0')['runtime'].dropna().quantile(q=0.8)
# Out:
# 121.0

# %% [markdown]
# # Movielens: média dos filmes com pelo menos 10 votos

# %%
print("Média dos filmes com pelo menos 10 votos", nota_media_dos_filmes_com_pelo_menos_10_votos.mean())
# Out:
# Média dos filmes com pelo menos 10 votos 3.4320503405352594

# %%
nota_media_dos_filmes_com_pelo_menos_10_votos[0:1].mean()
# Out:
# 3.9209302325581397

# %%
len(nota_media_dos_filmes_com_pelo_menos_10_votos)
# Out:
# 2269

# %%
medias = list()
for i in range(1, len(nota_media_dos_filmes_com_pelo_menos_10_votos)):
  medias.append(nota_media_dos_filmes_com_pelo_menos_10_votos[0:i].mean())

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(medias)

# %%
import numpy as np

np.random.seed(75243)
temp = nota_media_dos_filmes_com_pelo_menos_10_votos.sample(frac=1)

medias = list()
for i in range(1, len(temp)):
  medias.append(temp[0:i].mean())

plt.plot(medias)

# %%
np.random.seed(75243)
temp = nota_media_dos_filmes_com_pelo_menos_10_votos.sample(frac=1)

medias = [temp[0:i].mean() for i in range(1, len(temp))]

plt.plot(medias)

# %%
from statsmodels.stats.weightstats import zconfint

zconfint(nota_media_dos_filmes_com_pelo_menos_10_votos)
# Out:
# (3.4112459477469557, 3.452854733323563)

# %%
from statsmodels.stats.weightstats import DescrStatsW

descr_todos_com_10_votos = DescrStatsW(nota_media_dos_filmes_com_pelo_menos_10_votos)
descr_todos_com_10_votos.tconfint_mean()
# Out:
# (3.411234839229381, 3.4528658418411395)

# %% [markdown]
# # Vamos analisar o filme 1...

# %%
filmes = pd.read_csv("movies.csv")
filmes.query("movieId==1")
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
notas1 = notas.query("movieId == 1")
notas1.head()
# Out:
#       userId  movieId  rating   timestamp
# 0          1        1     4.0   964982703
# 516        5        1     4.0   847434962
# 874        7        1     4.5  1106635946
# 1434      15        1     2.5  1510577970
# 1667      17        1     4.5  1305696483

# %%
ax = sns.distplot(notas1['rating'])
ax.set(xlabel = "Notas médias", ylabel= "Densidade")
ax.set_title("Distribuição Para Notas para o Toy Story")
# Out:
# <ipython-input-48-140870b0e2f7>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(notas1['rating'])
# Text(0.5, 1.0, 'Distribuição Para Notas para o Toy Story')

# %%
ax = sns.boxplot(notas1['rating'], orient='h')
ax.set(xlabel = "Nota")
ax.set_title("Distribuição de nota para o Toy Story")
# Out:
# Text(0.5, 1.0, 'Distribuição de nota para o Toy Story')

# %%
notas1['rating'].mean()
# Out:
# 3.9209302325581397

# %%
notas1['rating'].count()
# Out:
# 215

# %%
zconfint(notas1['rating'])
# Out:
# (3.8093359183563402, 4.032524546759939)

# %%
from statsmodels.stats.weightstats import ztest

ztest(notas1['rating'], value = nota_media_dos_filmes_com_pelo_menos_10_votos.mean())
# Out:
# (8.586342305916732, 8.978190401885648e-18)

# %% [markdown]
# 8.978190401885648e-18 é um valor minusculo, então a media do Toy Story não pode ser igual a media dos filmes no geral.
# Rejeitamos a hipotese de Toy Story, no mundo real, ter a mesma media que a media de todos os filmes.

# %%
np.random.seed(75241)
temp = notas1.sample(frac=1)['rating']

def calcula_teste(i):
  media = temp[0:i].mean()
  stat, p = ztest(temp[0:i], value = nota_media_dos_filmes_com_pelo_menos_10_votos.mean())
  return(i, media, p)

valores = np.array([calcula_teste(i) for i in range(2, len(temp))])

plt.plot(valores[:,0], valores[:,1])
#eixo x = valores[:,0] Quantidade de Amostras
#eixo y = valores[:,1] Media das notas

plt.plot(valores[:,0], valores[:,2])
#eixo x = valores[:,0] Quantidade de Amostras
#eixo y = valores[:,2] P value
plt.hlines(y = 0.05, xmin= 2, xmax = len(temp), colors='g')

# %% [markdown]
# A visualização do P value em grafico não é comum, mas é bom para entender que dependendo da quantidade de valores na amostra poderiamos ter entendido que a nossa hipotese(Toy Story ter a mesma media de notas que os filmes no geral) seria aceita, até os primeiros 45 registros. Como temos muitos dados e olhamos para eles, vemos que essa hipotese não é real, descartamos ela.

# %% [markdown]
# # Comparação de dois conjuntos de amostras

# %%
zconfint(notas1['rating'], notas['rating'])
# Out:
# (0.2799245129192442, 0.5588219849631111)

# %% [markdown]
# O intervalo de confiança das notas do Toy Story são entre 0.27... e 0.55... maiores que as notas de todos os filmes

# %%
print('P value: ', ztest(notas1['rating'], notas['rating']))
# Out:
# P value:  (5.894327101501841, 3.762112778881965e-09)

# %% [markdown]
# De novo, podemos perceber que temos um numero bem menor que 0.5 que seria o 3.762112778881965e-09 o que nos mostra mais uma vez que a nossa hipotese alternativa (Media das notas do Toy Store é maior que as medias dos filmes) está correta.

# %%
from scipy.stats import ttest_ind

ttest_ind(notas['rating'], notas1['rating'])
# Out:
# Ttest_indResult(statistic=-5.894327101501841, pvalue=3.774003138720876e-09)

# %%
descr_todas_as_notas = DescrStatsW(notas['rating'])
descr_toy_story = DescrStatsW(notas1['rating'])

comparacao = descr_todas_as_notas.get_compare(descr_toy_story)
comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
comparacao.summary(use_t= True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
plt.boxplot([notas['rating'], notas1['rating']], labels=['Notas as notas', 'Notas do Toy Story'])
plt.title('Distribuição das notas de acordo com filmes')
# Out:
# Text(0.5, 1.0, 'Distribuição das notas de acordo com filmes')

# %%
plt.boxplot([notas['rating'], notas1[3:12]['rating']], labels=['Notas as notas', 'Notas do Toy Story do 3 ao 12'])
plt.title('Distribuição das notas de acordo com filmes')
# Out:
# Text(0.5, 1.0, 'Distribuição das notas de acordo com filmes')

# %%
descr_todas_as_notas = DescrStatsW(notas['rating'])
descr_toy_story = DescrStatsW(notas1[3:12]['rating'])

comparacao = descr_todas_as_notas.get_compare(descr_toy_story)
comparacao.summary(use_t = True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Novamente vemos uma analise com poucos dados e entendemos como é importante ter muitas amostras no dataframe(base de dados).
# Aqui o P value é de 0.8 e aceita a nossa hipotese de notas gerais é igual a do Toy Story, porém podemos também observar que o intervalo de confiança tem uma margem muito grande, indo de -0.73 até 0.62. Como pode ser pra mais ou menos assumir que tem o mesmo valor ou não temos dados suficientes, o intervalo de confiança muito grande nos mostra uma desconfiança da qualidade do nosso dataset/dataframe/database(ou como quiser chamar kkkk).

# %% [markdown]
# *PS: Por padrão o DescrStatsW.get_compare() utiliza o Z teste, mas nós sabemos que o Z teste é utilizado para grandes bases de dados, como não é o caso, estamos pegando um corte de terceiro registro até o decissimo primeiro(notas1[3:12]) ativamos o use_t como True para utilizar poucos dados.*

# %% [markdown]
# # Comparar a média de dois filmes

# %%
filmes.query('movieId in [1, 593, 72226]')
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 510       593  Silence of the Lambs, The (1991)
# 7180    72226          Fantastic Mr. Fox (2009)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 510                         Crime|Horror|Thriller
# 7180    Adventure|Animation|Children|Comedy|Crime

# %%
notas593 = notas.query('movieId == 593')
notas72226 = notas.query('movieId == 72226')

plt.boxplot([notas1['rating'], notas593['rating'], notas72226['rating']], labels=['Toy Story', 'Silence of the Lambs', 'Fantastic Mr. Fox'])
plt.title('Distribuição das notas de acordo com filmes')
# Out:
# Text(0.5, 1.0, 'Distribuição das notas de acordo com filmes')

# %%
notas72226.describe()
# Out:
#            userId  movieId     rating     timestamp
# count   18.000000     18.0  18.000000  1.800000e+01
# mean   329.722222  72226.0   4.083333  1.395218e+09
# std    174.748157      0.0   0.895249  9.459862e+07
# min     73.000000  72226.0   1.500000  1.262899e+09
# 25%    167.000000  72226.0   4.000000  1.279706e+09
# 50%    326.000000  72226.0   4.250000  1.441777e+09
# 75%    466.250000  72226.0   4.500000  1.471770e+09
# max    610.000000  72226.0   5.000000  1.498522e+09

# %%
sns.boxplot(x = 'movieId', y = 'rating', data = notas.query('movieId in (1, 593, 72226)'))
# Out:
# <Axes: xlabel='movieId', ylabel='rating'>

# %%
notas.query('movieId in [1, 593, 72226]').groupby('movieId').count()
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 593         279     279        279
# 72226        18      18         18

# %%
descr_1 = DescrStatsW(notas1['rating'])
descr_593 = DescrStatsW(notas593['rating'])

comparacao = descr_1.get_compare(descr_593)
comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
descr_72226 = DescrStatsW(notas72226['rating'])
descr_593 = DescrStatsW(notas593['rating'])

comparacao = descr_72226.get_compare(descr_593)
comparacao.summary(use_t= True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
comparacao = descr_1.get_compare(descr_72226)
comparacao.summary(use_t= True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
from scipy.stats import normaltest

_, p = normaltest(notas1['rating'])
p
# Out:
# 0.00011053430732728716

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.normaltest.html
#
# "This function tests the null hypothesis that a sample comes from a normal distribution."
# Ou seja essa normalização se espera que os dados venham de uma base de dados que represente uma normal, como o nosso tem uma assimetria a esquerda, ele descarta a hipotese nula(0.00011053430732728716
#  < 0.5) ou seja não vem de uma normal, ou seja, não podemos aplicar Z teste ou T teste. Pois estes precisam que os dados sejam representados por uma normal.

# %%
from scipy.stats import ranksums

_, p = ranksums(notas1['rating'], notas593['rating'])
p
# Out:
# 0.0003267718756440693

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ranksums.html
#
# "The Wilcoxon rank-sum test tests the **null hypothesis that two sets of measurements are drawn from the same distribution**. The **alternative hypothesis is that values in one sample are more likely to be larger than the values in the other sample**."
#
# Vamos reparar que não fala sobre media, aqui esse metodo nos diz que geralmente as notas aleatores de um filme (Silence of the Lambs) serão maiores que a de outro (Toy Story), que foram os nossos casos.
#
# Então nesta hipotese de notas maiores nós aceitamos a hipose alternativa. Por que o valor 0.0003267718756440693 é menor do que 0.5 se fosse maior aceitariamos a nula.

# %% [markdown]
# PS: Como não sabemos qual é a distribuição correta para os nossos dados e sabemos que ele não é uma distribuição normal, nós rejeitamos a hipotese nula.
